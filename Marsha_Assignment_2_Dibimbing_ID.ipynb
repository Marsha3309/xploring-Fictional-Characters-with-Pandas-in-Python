# %%
import pandas as pd

df = pd.read_csv('/content/fictional_characters.csv')

# %%
df
# Out:
#         Character Name  Media Type                               Media Source  \
# 0       Jeffrey Powell       Novel          Adaptive intermediate flexibility
# 1      Amanda Williams    Webcomic     Stand-alone fault-tolerant flexibility
# 2           Ryan Terry       Novel  Pre-emptive attitude-oriented methodology
# 3          Diana Huang       Novel    Innovative clear-thinking knowledgebase
# 4       Olivia Collier  Video Game        Profound homogeneous data-warehouse
# ...                ...         ...                                        ...
# 1495     Paula Rodgers       Novel            Synchronized maximized extranet
# 1496  Elizabeth Knight     TV Show          Centralized system-worthy project
# 1497   Krista Faulkner    Webcomic            Object-based value-added access
# 1498   Valerie Freeman  Video Game              Optional user-facing software
# 1499     Gregory Myers    Webcomic            Optimized content-based archive
#
#          Genre         Role           Personality Traits  \
# 0     Thriller   Antagonist     candidate, hundred, case
# 1      Fantasy   Antagonist      through, new, community
# 2      Mystery         Hero      defense, medical, phone
# 3      Romance   Antagonist       morning, check, strong
# 4      Fantasy  Protagonist  appear, family, environment
# ...        ...          ...                          ...
# 1495   Fantasy  Protagonist            gun, enough, talk
# 1496   Fantasy       Mentor         reveal, region, item
# 1497   Fantasy         Hero        them, despite, growth
# 1498    Sci-Fi   Antagonist       computer, foreign, sea
# 1499    Sci-Fi      Villain    garden, toward, community
#
#                                               Backstory  \
# 0     Body now hope likely cup under world could total.
# 1     Perhaps sometimes give evidence many fact each...
# 2     North get on listen avoid better whom recent m...
# 3     Environment activity brother ten gun provide r...
# 4     Event make finally central whom forward enter ...
# ...                                                 ...
# 1495  Beautiful we education work face serve far hos...
# 1496  Leave trial stuff another stand help imagine a...
# 1497  Memory cup back fly partner fire defense analy...
# 1498  Nothing herself over population whole record c...
# 1499  Develop teach audience ago picture event once ...
#
#                Skills/Abilities  \
# 0       option, try, difference
# 1         year, service, debate
# 2            floor, threat, bad
# 3       stay, attorney, reality
# 4            word, pull, enough
# ...                         ...
# 1495   probably, process, civil
# 1496   style, traditional, once
# 1497        answer, really, try
# 1498  suggest, another, concern
# 1499           player, yet, bar
#
#                                  Appearance Description Alignment  \
# 0               None act worker order seem system pass.   Villain
# 1     American on clear could girl result its by ano...   Villain
# 2     Hundred couple one anything the read color gue...      Hero
# 3                  Reflect blue travel space onto miss.   Neutral
# 4     Tend us people special speak item size human h...      Hero
# ...                                                 ...       ...
# 1495                               Cut light tough ago.   Neutral
# 1496                Meet return two surface idea speak.   Villain
# 1497     Beat there check manager out recognize people.      Hero
# 1498  Partner political material picture role citize...      Hero
# 1499  Knowledge finish affect half remain list kitch...   Neutral
#
#              Interests/Hobbies  \
# 0         so, allow, establish
# 1     since, describe, current
# 2              sing, war, data
# 3             plan, also, most
# 4           throw, sort, tough
# ...                        ...
# 1495    yes, laugh, difference
# 1496      system, second, seem
# 1497     machine, minute, near
# 1498    position, fear, travel
# 1499         will, scene, wife
#
#                                           Relationships  \
# 0     Morning weight vote right serve ago book project.
# 1     Attention later left exactly response rich des...
# 2     Different ahead crime tonight no pressure brea...
# 3           Mr rich remain sense real someone personal.
# 4     Among magazine range fact goal common indicate...
# ...                                                 ...
# 1495  Central range all policy interesting child alo...
# 1496  Sometimes race well talk end religious onto to...
# 1497  Success meeting democratic stock consider end ...
# 1498  Address hospital help real mind claim scientis...
# 1499  Action respond read key speak coach three sea ...
#
#                                     Significance/Impact  \
# 0     Way forget year network degree off they outsid...
# 1                 Step most community turn simple item.
# 2                  Certain card case main indicate you.
# 3     Shoulder often these collection single color p...
# 4      Bill treat image population evening its protect.
# ...                                                 ...
# 1495  Method lead decision physical fear address sea...
# 1496           Past TV his still compare score success.
# 1497  Clearly city these officer part lawyer country...
# 1498         Store garden enter young environment some.
# 1499   Follow sound seven yourself show rate on career.
#
#                                             Description  \
# 0     Maintain minute evening sea. Move anything thi...
# 1     Hear side third article model research conditi...
# 2     Set wide land within medical. Bit read effect ...
# 3     Represent front meeting deep. Apply culture ea...
# 4     Result college yet theory safe. Radio sense ro...
# ...                                                 ...
# 1495  Strategy religious project firm admit. Those w...
# 1496  Heart choose then miss. Story thing movement g...
# 1497  Ever enjoy new remember into. Look able bag kn...
# 1498  Defense improve reach sport either war pay cup...
# 1499  Style religious game politics his very. Mainta...
#
#                               Scenario/Dialogue Example
# 0     Tend fast quality represent audience and red s...
# 1     Ahead Congress bit choose relationship let nat...
# 2     Daughter control among campaign bill lead shar...
# 3      Thing eye use seven chance put least as product.
# 4     Large despite none body movie might prepare ea...
# ...                                                 ...
# 1495  College manager particular long since increase...
# 1496  Center recognize question power world activity...
# 1497  Show sometimes avoid hotel radio these bad eco...
# 1498  Find success hospital really decision agree de...
# 1499  Account hear maintain director series agent Re...
#
# [1500 rows x 15 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1500 entries, 0 to 1499
# Data columns (total 15 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Character Name             1500 non-null   object
#  1   Media Type                 1500 non-null   object
#  2   Media Source               1500 non-null   object
#  3   Genre                      1500 non-null   object
#  4   Role                       1500 non-null   object
#  5   Personality Traits         1500 non-null   object
#  6   Backstory                  1500 non-null   object
#  7   Skills/Abilities           1500 non-null   object
#  8   Appearance Description     1500 non-null   object
#  9   Alignment                  1500 non-null   object
#  10  Interests/Hobbies          1500 non-null   object
#  11  Relationships              1500 non-null   object
#  12  Significance/Impact        1500 non-null   object
#  13  Description                1500 non-null   object
#  14  Scenario/Dialogue Example  1500 non-null   object
# dtypes: object(15)
# memory usage: 175.9+ KB

# %%
df.isna().sum()
# Out:
# Character Name               0
# Media Type                   0
# Media Source                 0
# Genre                        0
# Role                         0
# Personality Traits           0
# Backstory                    0
# Skills/Abilities             0
# Appearance Description       0
# Alignment                    0
# Interests/Hobbies            0
# Relationships                0
# Significance/Impact          0
# Description                  0
# Scenario/Dialogue Example    0
# dtype: int64

# %%
df.describe()
# Out:
#        Character Name Media Type                     Media Source    Genre  \
# count            1500       1500                             1500     1500
# unique           1491          5                             1499        6
# top      John Mathews    TV Show  Team-oriented asymmetric access  Fantasy
# freq                2        313                                2      267
#
#             Role         Personality Traits  \
# count       1500                       1500
# unique         6                       1500
# top     Sidekick  garden, toward, community
# freq         266                          1
#
#                                                 Backstory  Skills/Abilities  \
# count                                                1500              1500
# unique                                               1500              1500
# top     Develop teach audience ago picture event once ...  player, yet, bar
# freq                                                    1                 1
#
#                                    Appearance Description Alignment  \
# count                                                1500      1500
# unique                                               1500         3
# top     Knowledge finish affect half remain list kitch...      Hero
# freq                                                    1       517
#
#         Interests/Hobbies                                      Relationships  \
# count                1500                                               1500
# unique               1500                                               1500
# top     will, scene, wife  Action respond read key speak coach three sea ...
# freq                    1                                                  1
#
#                                      Significance/Impact  \
# count                                               1500
# unique                                              1500
# top     Follow sound seven yourself show rate on career.
# freq                                                   1
#
#                                               Description  \
# count                                                1500
# unique                                               1500
# top     Style religious game politics his very. Mainta...
# freq                                                    1
#
#                                 Scenario/Dialogue Example
# count                                                1500
# unique                                               1500
# top     Account hear maintain director series agent Re...
# freq                                                    1

# %%
df['Appearance Description'].describe()
# Out:
# count                                                  1500
# unique                                                 1500
# top       Knowledge finish affect half remain list kitch...
# freq                                                      1
# Name: Appearance Description, dtype: object

# %%
for column in df.columns:
    if df[column].dtype == 'object':
        # Jika kolom bertipe object, isi dengan mode
        df[column].fillna(df[column].mode()[0], inplace=True)
    else:
        # Jika kolom bertipe numerik, isi dengan mean
        df[column].fillna(df[column].mean(), inplace=True)
# Out:
# /tmp/ipython-input-17-3073414678.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[column].fillna(df[column].mode()[0], inplace=True)

# %%
df.isna().sum()
# Out:
# Character Name               0
# Media Type                   0
# Media Source                 0
# Genre                        0
# Role                         0
# Personality Traits           0
# Backstory                    0
# Skills/Abilities             0
# Appearance Description       0
# Alignment                    0
# Interests/Hobbies            0
# Relationships                0
# Significance/Impact          0
# Description                  0
# Scenario/Dialogue Example    0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1500 entries, 0 to 1499
# Data columns (total 15 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Character Name             1500 non-null   object
#  1   Media Type                 1500 non-null   object
#  2   Media Source               1500 non-null   object
#  3   Genre                      1500 non-null   object
#  4   Role                       1500 non-null   object
#  5   Personality Traits         1500 non-null   object
#  6   Backstory                  1500 non-null   object
#  7   Skills/Abilities           1500 non-null   object
#  8   Appearance Description     1500 non-null   object
#  9   Alignment                  1500 non-null   object
#  10  Interests/Hobbies          1500 non-null   object
#  11  Relationships              1500 non-null   object
#  12  Significance/Impact        1500 non-null   object
#  13  Description                1500 non-null   object
#  14  Scenario/Dialogue Example  1500 non-null   object
# dtypes: object(15)
# memory usage: 175.9+ KB

# %%
check_duplicate = df.duplicated().sum()

print(f"Jumlah data yang duplikat = {check_duplicate}")
# Out:
# Jumlah data yang duplikat = 0

# %%
df = df.drop_duplicates()

# %%
handle_duplicate = df.duplicated().sum()

print(f"Jumlah data yang duplikat = {handle_duplicate}")
# Out:
# Jumlah data yang duplikat = 0
